# %% [markdown]
# ### Assignments
# To complete this assignment, submit your solutions to the following tasks as a link to your Jupyter Notebook on GitHub.
#
# 1. Parallelize the following code using Dask's **@delayed** decorator and derive the task execution graph.

# %%
#def sum_up(l): #takes a list of numbers as input
#    return sum(l)

#def cube(n):
#    return n**3

#total = []
#for i in range(1,10):
#    total.append(cube(i))

#print(sum_up(total))

# %%
#this should sum up all of the cubes of the numbers.

# %%
#This will compute it.
from dask import delayed

@delayed
def sum_up(l): #takes a list of numbers as input
    return sum(l)

@delayed
def cube(n):
    return n**3

total = []
for i in range(1,10):
    total.append(cube(i))

print(sum_up(total).compute())
# Out:
# 2025

# %%
#delayed

@delayed
def sum_up(l): #takes a list of numbers as input
    return sum(l)

@delayed
def cube(n):
    return n**3

total = []
for i in range(1,10):
    total.append(cube(i))

print(sum_up(total))
# Out:
# Delayed('sum_up-a1d04ff5-2c10-42c3-abeb-3b6c35fc4760')

# %%
#delayed

@delayed
def sum_up(l): #takes a list of numbers as input
    return sum(l)

@delayed
def cube(n):
    return n**3

total = []
for i in range(1,10):
    total.append(cube(i))

total_sum=sum_up(total)
total_sum
# Out:
# Delayed('sum_up-c746df19-e5d1-447d-b4e7-625c39263f66')

# %%
sum_up(total).visualize()

# %%
sum_up(total).compute()
# Out:
# 2025

# %%
total_sum.visualize()

# %%
total_sum.compute()
# Out:
# 2025

# %% [markdown]
# 2. Parallelize the following code using Dask's **@delayed** decorator and derive the task execution graph.

# %%
# first two fibonacci numbers
#fibonacci_nums = [1,1]

# returns the nth fibonacci number
#def get_nth_fibonacci_number(n):
#    if n == 1:
#        return fibonacci_nums[0]
#    elif n == 2:
#        return fibonacci_nums[1]
#    else:
#        return get_nth_fibonacci_number(n-1) + get_nth_fibonacci_number(n-2)

#print(get_nth_fibonacci_number(10))

# %%
#each number is the sum of the two preceding numbers

# first two fibonacci numbers
fibonacci_nums = [1,1]

# returns the nth fibonacci number
def get_nth_fibonacci_number(n):
    if n == 1:
        return fibonacci_nums[0]
    elif n == 2:
        return fibonacci_nums[1]
    else:
        return get_nth_fibonacci_number(n-1) + get_nth_fibonacci_number(n-2)

print(get_nth_fibonacci_number(10))
# Out:
# 55

# %%
from dask import delayed
#delayed
# first two fibonacci numbers
fibonacci_nums = [1,1]

@delayed
# returns the nth fibonacci number
def get_nth_fibonacci_number(n):
    if n == 1:
        return fibonacci_nums[0]
    elif n == 2:
        return fibonacci_nums[1]
    else:
        return get_nth_fibonacci_number(n-1) + get_nth_fibonacci_number(n-2)

print(get_nth_fibonacci_number(10))
# Out:
# Delayed('get_nth_fibonacci_number-97a4e35b-f7ba-44f8-a491-c3c3331b76d7')

# %%
from dask import delayed
#delayed
# first two fibonacci numbers
fibonacci_nums = [1,1]

@delayed
# returns the nth fibonacci number
def get_nth_fibonacci_number(n):
    if n == 1:
        return fibonacci_nums[0]
    elif n == 2:
        return fibonacci_nums[1]
    else:
        return get_nth_fibonacci_number(n-1).compute() + get_nth_fibonacci_number(n-2).compute()

#print(get_nth_fibonacci_number(10))
fib = get_nth_fibonacci_number(10)

# %%
get_nth_fibonacci_number(10).visualize()

# %%
get_nth_fibonacci_number(10).compute()
# Out:
# 55

# %%
fib.visualize()

# %%
fib.compute()
# Out:
# 55

# %% [markdown]
# Submit your work below. You can also take a look at this example solution.
#
# https://drive.google.com/file/d/1BKm4EjvviJjj-Pdq0jlJrW8m_8CoHS_o/view?usp=sharing
