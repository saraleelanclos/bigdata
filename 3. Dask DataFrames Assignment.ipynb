# %% [markdown]
# ## Assignments
# In this assignment, you'll continue working with the Credit Card Fraud Detection dataset from Kaggle. Load the dataset before working on the following tasks.
#
# https://www.kaggle.com/mlg-ulb/creditcardfraud/download
#
#
# To complete this assignment, submit your solutions to the following tasks as a link to your Jupyter Notebook on GitHub.
#
#
# 1. How many transactions are there in total?
#
# 2. How many transactions are fraud, and how many are not fraud?
#
# 3. What is the maximum amount in fraud transactions?
#
# Submit your work below. You can also take a look at this example solution.
#
#
# https://drive.google.com/file/d/19bMnC6yJahYpmcECkZXFiFnb9UHbMwjT/view?usp=sharing

# %%
import warnings
warnings.filterwarnings("ignore")

from dask.distributed import Client, progress

client = Client(n_workers=4, threads_per_worker=2, memory_limit='2GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:50985' processes=4 threads=8, memory=8.00 GB>

# %%
# DataFrames implement the pandas API
import dask.dataframe as dd

# This loads the data into a Dask DataFrame
df = dd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/creditcard.csv')

# %%
print(df)
# Out:
# Dask DataFrame Structure:
#                 Time       V1       V2       V3       V4       V5       V6       V7       V8       V9      V10      V11      V12      V13      V14      V15      V16      V17      V18      V19      V20      V21      V22      V23      V24      V25      V26      V27      V28   Amount  Class
# npartitions=3
#                int64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  int64
#                  ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...    ...
# ...

# %%
df.dtypes
# Out:
# Time        int64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
# Dask DataFrame Structure:
#                   Time       V1       V2       V3       V4       V5       V6       V7       V8       V9      V10      V11      V12      V13      V14      V15      V16      V17      V18      V19      V20      V21      V22      V23      V24      V25      V26      V27      V28   Amount    Class
# npartitions=1
#                float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64
#                    ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...
# Dask Name: describe-numeric, 344 tasks

# %%
df = dd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/creditcard.csv', dtype={'Time': 'float64'})

# %%
df.describe().compute()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.187934e-15  3.384974e-16 -1.328443e-15  2.075692e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     49346.000000 -7.868600e-01 -5.536365e-01 -7.156553e-01 -7.067841e-01
# 50%     76029.000000  9.301532e-02  8.999754e-02  1.743346e-01  1.809941e-01
# 75%    138472.000000  1.912886e+00  8.916958e-01  1.373682e+00  1.012508e+00
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.707851e-16  1.494498e-15 -5.588401e-16  1.149614e-16 -2.403811e-15
# ...

# %% [markdown]
# 1. How many transactions are there in total?

# %%
len(df)
# Out:
# 284807

# %%
a = df.shape
a[0].compute(),a[1]
# Out:
# (284807, 31)

# %% [markdown]
# There are 284,807 transactions (rows) in total.

# %% [markdown]
# 2. How many transactions are fraud, and how many are not fraud?

# %%
fraud = df[df["Class"] ==1]
fraud
# Out:
# Dask DataFrame Structure:
#                   Time       V1       V2       V3       V4       V5       V6       V7       V8       V9      V10      V11      V12      V13      V14      V15      V16      V17      V18      V19      V20      V21      V22      V23      V24      V25      V26      V27      V28   Amount  Class
# npartitions=3
#                float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  int64
#                    ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...    ...
# ...

# %%
fraud.compute()
# Out:
#            Time        V1        V2        V3        V4        V5        V6  \
# 541       406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623       472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920     4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108     6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329     7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...         ...       ...       ...       ...       ...       ...       ...
# 38075  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 38355  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 38361  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 39356  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 39886  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %% [markdown]
# There are 492 fraud transactions.

# %%
notfraud = df[df["Class"] ==0]
notfraud
# Out:
# Dask DataFrame Structure:
#                   Time       V1       V2       V3       V4       V5       V6       V7       V8       V9      V10      V11      V12      V13      V14      V15      V16      V17      V18      V19      V20      V21      V22      V23      V24      V25      V26      V27      V28   Amount  Class
# npartitions=3
#                float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  float64  int64
#                    ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...      ...    ...
# ...

# %%
notfraud.compute()
# Out:
#            Time         V1         V2        V3        V4        V5        V6  \
# 0           0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1           0.0   1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2           1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3           1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4           2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...         ...        ...        ...       ...       ...       ...       ...
# 43014  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 43015  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 43016  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 43017  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 43018  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
# ...

# %% [markdown]
# There are 284315 not fraud transactions.

# %%
df["Class"].unique().compute()
# Out:
# 0    0
# 1    1
# Name: Class, dtype: int64

# %%
df.groupby("Class")["Time"].count().compute()
# Out:
# Class
# 0    284315
# 1       492
# Name: Time, dtype: int64

# %% [markdown]
# 3. What is the maximum amount in fraud transactions?

# %%
fraud.describe().compute()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948    3.623778   -7.033281    4.542029
# std     47835.365138    6.783687    4.291216    7.110937    2.873318
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     26556.000000   -3.434791    1.291527   -6.502294    2.572046
# 50%     56806.000000   -0.902340    2.844795   -4.769752    4.284346
# 75%    102622.000000    0.088907    5.262312   -1.601052    6.419365
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -3.151225   -1.397737   -5.568731    0.570636   -2.581123  ...
# std      5.372468    1.858124    7.206773    6.797831    2.500896  ...
# ...

# %%
df[df.Class==1]["Amount"].max().compute()
# Out:
# 2125.87

# %% [markdown]
# The maximum fraud transaction amount is 2125.87.

# %%
client.close()
